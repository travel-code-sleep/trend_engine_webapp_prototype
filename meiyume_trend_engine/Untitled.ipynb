# %%
# %load_ext lab_black

# %%
from bte_category_page_data_and_plots import (
    cat_page_item_package_oz_df,
    cat_page_top_products_df,
)

# %%
cat_page_item_package_oz_df
# Out:
#      source                category                  product_type   item_size  \
# 0        uk               bath-body       baby & child toiletries     8.45 oz
# 1        uk               bath-body       baby & child toiletries     6.76 oz
# 2        uk               bath-body       baby & child toiletries    16.91 oz
# 3        uk               bath-body       baby & child toiletries    10.14 oz
# 4        uk               bath-body       baby & child toiletries    13.53 oz
# ...     ...                     ...                           ...         ...
# 3992     us  travel-size-toiletries  vitamins-for-hair-skin-nails    10 count
# 3993     us  travel-size-toiletries  vitamins-for-hair-skin-nails  10 gummies
# 3994     us  travel-size-toiletries  vitamins-for-hair-skin-nails   8 gummies
# 3995     us  travel-size-toiletries       woody-earthy-fragrances     0.25 oz
# 3996     us  travel-size-toiletries       woody-earthy-fragrances        1 oz
#
#       product_count
# 0                24
# 1                23
# 2                22
# 3                12
# 4                10
# ...             ...
# 3992              2
# 3993              1
# 3994              1
# 3995              1
# 3996              1
#
# [3997 rows x 5 columns]

# %%
cat_page_top_products_df
# Out:
#      source                category                  product_type  \
# 0        uk               bath-body       baby & child toiletries
# 1        uk               bath-body       baby & child toiletries
# 2        uk               bath-body       baby & child toiletries
# 3        uk               bath-body       baby & child toiletries
# 4        uk               bath-body       baby & child toiletries
# ...     ...                     ...                           ...
# 4859     us  travel-size-toiletries  vitamins-for-hair-skin-nails
# 4860     us  travel-size-toiletries  vitamins-for-hair-skin-nails
# 4861     us  travel-size-toiletries  vitamins-for-hair-skin-nails
# 4862     us  travel-size-toiletries        wellness-tools-rollers
# 4863     us  travel-size-toiletries       woody-earthy-fragrances
#
#            prod_id               brand  \
# 0     bts_10195185
# 1     bts_10195186
# 2     bts_10258150
# 3     bts_10258119
# 4     bts_10248553
# ...            ...                 ...
# 4859   sph_p444434  SEPHORA COLLECTION
# 4860   sph_p444435  SEPHORA COLLECTION
# 4861   sph_p450145  SEPHORA COLLECTION
# 4862   sph_p458733  SEPHORA COLLECTION
# 4863   sph_p110113   NARCISO RODRIGUEZ
#
#                                            product_name  adjusted_rating  \
# 0                     Bepanthen Nappy Rash Ointment 30g            4.874
# 1                    Bepanthen Nappy Rash Ointment 100g            4.874
# 2                  Oilatum Daily Junior Bath Foam 300ml            4.677
# 3           Oilatum Daily Junior Head to Toe Wash 300ml            4.650
# 4     Childs Farm Watermelon & Pineapple Hair & Body...            4.553
# ...                                                 ...              ...
# 4859  SEPHORA COLLECTION Sephora Collection x OLLY: ...            4.000
# 4860  SEPHORA COLLECTION Sephora Collection x OLLY: ...            4.000
# 4861  SEPHORA COLLECTION Sephora Collection x OLLY: ...            3.714
# 4862  SEPHORA COLLECTION Mini Rose Quartz Facial Roller            4.000
# 4863          Narciso Rodriguez for her Eau de Toilette            4.250
#
#      small_size_price big_size_price first_review_date
# 0                £3.3           £3.3
# 1               £7.29          £7.29
# 2               £4.99          £4.99
# 3               £4.99          £4.99
# 4               £2.99          £2.99
# ...               ...            ...               ...
# 4859             $7.0           $7.0        2019-05-26
# 4860             $7.0           $7.0        2019-06-13
# 4861             $7.0           $7.0        2020-06-18
# 4862            $12.0          $12.0        2020-07-12
# 4863            $29.0          $58.0        2008-09-02
#
# [4864 rows x 10 columns]

# %%
PACKAGING_SIZE = "item_size"
NUMBER_OF_PRODUCTS = "product_count"
PRODUCT_DESCRIPTION = "product_name"
PRODUCT_RATING_ADJUSTED = "adjusted_rating"
DATE_FIRST_REVIEWED = "first_reviwe_date"
PRICE_LOW = "small_size_price"
PRICE_HIGH = "big_size_price"
